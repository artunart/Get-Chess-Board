# %%
if 'utils.utils' in dir():
    del utils.utils 
import utils.utils
import os
import matplotlib.pyplot as plt

# %%
fname="data/raw/boards/Screen Shot 2021-09-30 at 5.07.40 PM_brd.png"
image = plt.imread(fname)
print(image.shape)
print(1358*1352*4)
8*8*169*169*4
# Out:
# (1358, 1352, 4)
# 7344064
# 7311616

# %%
image_divided = utils.utils.divide_board(image, (0,0),(image.shape[0], image.shape[1]))
# Out:
# (1352, 1352, 4)

# %%
plt.imshow(image_divided[0][2])

# %%
plt.imshow(image_divided[36][2])

# %%
plt.imshow(image_divided[63][2])

# %%
board_path = "data/raw/boards"
square_path = "data/raw/squares"
board_fnames = [board_path+'/'+_ for _ in os.listdir(board_path) if _[0]!='.']
utils.utils.boards_to_squares(board_fnames, square_path)
# Out:
# (1352, 1352, 4)
